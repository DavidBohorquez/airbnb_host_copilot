# %% [markdown]
# # Host Copilot — scratch exploration
#
# Free space to poke at the data and test each milestone interactively. Not part of the package.
#
# The `host_copilot` package is importable because `pyproject.toml` sets `pythonpath = ["host_copilot/src"]`.
# Run the kernel from the repo root.

# %%
from host_copilot.config import get_settings
s = get_settings()
print(s.embed_model, s.data_path)
# Out:
# intfloat/multilingual-e5-small C:\Users\David BOHORQUEZ\Documents\ynov_m1\DataScience\host_copilot\data_airbnb_bordeaux

# %%
# M1: once loaders are implemented
from host_copilot.data.loaders import load_listings
from host_copilot.documents import listing_to_document

df = load_listings()
print(df.shape)
print(listing_to_document(df.iloc[0])[:300])
# Out:
# (7619, 80)
# Spectacular view, full air-con, elevator
# Imagine yourself relaxing on a 12m² private terrace, glass of Bordeaux wine in hand, as you gaze out at the Porte de Bourgogne, the majestic Pont de Pierre, and the shimmering Garonne River. This is the charm of Bordeaux Terrace Apartment – where modern comfo

# %%
print(df.columns)
df.iloc[0]
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'peer_key'],
#       dtype='str')
# id                                                                           222887
# listing_url                                     https://www.airbnb.com/rooms/222887
# scrape_id                                                            20250918041729
# last_scraped                                                             2025-09-18
# source                                                                  city scrape
#                                                                ...
# calculated_host_listings_count_entire_homes                                       4
# calculated_host_listings_count_private_rooms                                      0
# calculated_host_listings_count_shared_rooms                                       0
# reviews_per_month                                                               0.8
# peer_key                                           Bordeaux Sud|Entire home/apt|3-4
# Name: 0, Length: 80, dtype: object

# %%
listing_to_document(df.iloc[0])
# Out:
# 'Spectacular view, full air-con, elevator\nImagine yourself relaxing on a 12m² private terrace, glass of Bordeaux wine in hand, as you gaze out at the Porte de Bourgogne, the majestic Pont de Pierre, and the shimmering Garonne River. This is the charm of Bordeaux Terrace Apartment – where modern comfort meets historic elegance.<br /><br />Whether you\'re preparing a meal in the well-equipped kitchen, enjoying al fresco dining, or simply soaking in the view, this stylish apartment offers a peaceful escape in the heart of the city.\nAmenities: ["Host greets you", "Refrigerator", "Fast wifi \\u2013 395 Mbps", "Toaster", "Hair dryer", "Ethernet connection", "Pack \\u2019n play/Travel crib", "Drying rack for clothing", "High chair", "Clothing storage: wardrobe", "Dedicated workspace", "Baking sheet", "Blender", "Paid parking garage off premises", "Wine glasses", "Bed linens", "Iron", "Harmon Kardon speaker  Bluetooth sound system", "Elevator", "Conditioner", "First aid kit", "Free washer \\u2013 In unit", "Carbon monoxide alarm", "Waterfront", "Shower gel", "Long term stays allowed", "Private entrance", "City skyline view", "Books and reading material", "Heating", "Cooking basics", "Coffee maker", "Extra pillows and blankets", "River view", "20 inch HDTV with standard cable", "Cleaning products", "Portable fans", "Outdoor furniture", "Coffee", "Essentials", "Oven", "Hangers", "Microwave", "Crib", "Central air conditioning", "Free dryer \\u2013 In unit", "Body soap", "Private patio or balcony", "Hot water kettle", "Dishes and silverware", "Hot water", "Shampoo", "Induction stove", "Smoke alarm", "Kitchen", "Dining table"]\nNeighbourhood: Bordeaux Sud\nScores - rating: 4.83, cleanliness: 4.74, location: 4.76, value: 4.7'

# %%
df.head(n=5)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  222887  https://www.airbnb.com/rooms/222887  20250918041729   2025-09-18
# 1  317273  https://www.airbnb.com/rooms/317273  20250918041729   2025-09-18
# 2  317658  https://www.airbnb.com/rooms/317658  20250918041729   2025-09-18
# 3  333031  https://www.airbnb.com/rooms/333031  20250918041729   2025-09-18
# 4  365993  https://www.airbnb.com/rooms/365993  20250918041729   2025-09-18
#
#         source                                               name  \
# 0  city scrape           Spectacular view, full air-con, elevator
# 1  city scrape       Luxury, spacious, patio, near public gardens
# 2  city scrape  Key to Bordeaux · fairytale view, 2 bd + elevator
# 3  city scrape      STUDIO BORDEAUX TRIANGLE D OR ***** Climatisé
# 4  city scrape                   Modern&comfortable 3 rooms apart
#
#                                          description  \
# 0  Imagine yourself relaxing on a 12m² private te...
# 1  Bordeaux City Gardens is a luxurious one-bedro...
# 2  The Key to Bordeaux has a view over the ‘fairy...
# 3  Come and discover Bordeaux and spend a few day...
# 4  The apartment is a 3 rooms in ground floor, re...
#
#                                neighborhood_overview  \
# 0  ✔ NEARBY MARKETS – Located near St Michel anti...
# 1  ✔ PRIME LOCATION – Situated near the Bordeaux ...
# 2  ✔ FAIRYTALE VIEW – Overlooking the enchanting ...
# 3                                                NaN
# 4  Quiet and pleasant.<br />Close to shops (500m)...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/8f2b210e-3c0e...  1156398  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...  1156398  ...
# 2  https://a0.muscache.com/pictures/a5da668b-39dd...  1156398  ...
# 3  https://a0.muscache.com/pictures/3643e626-de1f...  1697156  ...
# 4  https://a0.muscache.com/pictures/fca62587-5814...  1847986  ...
#
#   review_scores_location review_scores_value        license instant_bookable  \
# 0                   4.76                4.70  3306300031048                t
# 1                   4.97                4.78  33063001366CB                t
# 2                   4.97                4.77  33063001225CF                t
# 3                   4.98                4.84  3306300055979                f
# 4                   4.71                4.74            NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              4                                           4
# 1                              4                                           4
# 2                              4                                           4
# 3                              2                                           1
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              0.80
# 1                                           0              0.64
# 2                                           0              1.00
# 3                                           0              3.55
# 4                                           0              0.45
#
#                                             peer_key
# 0                   Bordeaux Sud|Entire home/apt|3-4
# 1  Chartrons - Grand Parc - Jardin Public|Entire ...
# 2        Centre ville (Bordeaux)|Entire home/apt|5-6
# 3        Centre ville (Bordeaux)|Entire home/apt|1-2
# 4                          Bgles|Entire home/apt|5-6
#
# [5 rows x 80 columns]
